# %%
# !pip install fuzzywuzzy
# !pip install transformers
# !pip install spacy

# %%
# !pip install sentence_transformers

# %%
# !python -m spacy download en_core_web_trf
# Out:
# ...
#      ---------------------------------------- 0.0/457.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/457.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/457.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/457.4 MB 325.1 kB/s eta 0:23:28
#      -------------------------------------- 0.0/457.4 MB 326.8 kB/s eta 0:23:20
#      -------------------------------------- 0.1/457.4 MB 521.8 kB/s eta 0:14:37
#      -------------------------------------- 0.1/457.4 MB 544.7 kB/s eta 0:14:00
#      -------------------------------------- 0.2/457.4 MB 778.2 kB/s eta 0:09:48
#      -------------------------------------- 0.3/457.4 MB 871.5 kB/s eta 0:08:45
#      -------------------------------------- 0.3/457.4 MB 803.7 kB/s eta 0:09:29
#      ---------------------------------------- 0.4/457.4 MB 1.0 MB/s eta 0:07:28
#      ---------------------------------------- 0.5/457.4 MB 1.1 MB/s eta 0:06:59
# ...

# %%
# !pip install faiss-cpu
# Out:
# ...
#   Using cached faiss_cpu-1.10.0-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# ...
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.7 MB 495.5 kB/s eta 0:00:28
#    ---------------------------------------- 0.1/13.7 MB 563.7 kB/s eta 0:00:25
#     --------------------------------------- 0.2/13.7 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.5/13.7 MB 2.2 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/13.7 MB 2.5 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/13.7 MB 2.8 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/13.7 MB 3.0 MB/s eta 0:00:05
#    --- ------------------------------------ 1.2/13.7 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.5/13.7 MB 3.3 MB/s eta 0:00:04
# ...

# %%
import spacy
import requests
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import openai  # Import OpenAI library

# Load NLP Models
nlp = spacy.load("en_core_web_trf")  # Better than 'en_core_web_sm'
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")  # For better entity similarity matching

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = "AIzaSyCKL_3TpCL7mt8dincmwy45WrFaenyosZY"

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}
import openai
import json
import faiss
import pickle
import re
import helper

def extract_entities(text, examples):
    """
    Extract named entities from the given text using OpenAI's language model and similar examples.
    """
    # Convert examples to a formatted string
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])

    # Construct system prompt
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    # Call OpenAI API
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    # Extract response text
    response_text = response['choices'][0]['message']['content']

    # Extract JSON safely
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))  # Return unique entities


def main():
    """ Main function to process the test data, find similar examples, and extract entities. """
    
    # Load data
    test_data = json.load(open("test_data.json", "r"))
    train_data = json.load(open("train_data.json", "r"))

    # Load FAISS index
    index = faiss.read_index("training_data_vectors.faiss")

    # Store predicted entities
    predicted_entities_with_similarity = []

    for text in test_data['text']:
        # Generate embedding
        embedding = helper.get_embeddings_oai([text])

        # Ensure 2D shape for FAISS search
        D, I = index.search(embedding.reshape(1, -1), 10)

        # Get similar examples
        similar_examples = [(train_data['text'][i], train_data['entities'][i]) for i in I[0]]

        # Extract entities
        entities = extract_entities(text, similar_examples)

        # Store results
        predicted_entities_with_similarity.append(entities)

    # Save extracted entities
    with open("predicted_entities_with_similarity.pkl", "wb") as f:
        pickle.dump(predicted_entities_with_similarity, f)



import openai
import torch
from sentence_transformers import SentenceTransformer, util

# Load the Sentence Transformer model
semantic_model = SentenceTransformer('all-MiniLM-L6-v2')

# Set your OpenAI API key
openai.api_key = OPENAI_API_KEY

def get_openai_embedding(text):
    """Get embeddings from OpenAI's API."""
    response = openai.Embedding.create(
        model="text-embedding-ada-002",  # Specify the OpenAI model
        input=text
    )
    return response['data'][0]['embedding']

def semantic_match(name1, name2, threshold=0.85):
    """Use Sentence Transformers and OpenAI for semantic similarity matching."""
    try:
        # Encode the names to get their embeddings
        embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
        embedding2 = semantic_model.encode(name2, convert_to_tensor=True)

        # Compute cosine similarity using Sentence Transformers
        similarity_st = util.pytorch_cos_sim(embedding1, embedding2).item()

        # Get embeddings from OpenAI
        openai_embedding1 = get_openai_embedding(name1)
        openai_embedding2 = get_openai_embedding(name2)

        # Compute cosine similarity using OpenAI embeddings
        similarity_openai = util.pytorch_cos_sim(
            torch.tensor(openai_embedding1),
            torch.tensor(openai_embedding2)
        ).item()

        # Average the similarities from both models
        average_similarity = (similarity_st + similarity_openai) / 2

        # Return whether the average similarity meets the threshold
        return average_similarity >= threshold

    except Exception as e:
        print(f"Error in semantic_match: {e}")
        return False

# Example usage
"""if __name__ == "__main__":
    name1 = "John Doe"
    name2 = "Jonathan Doe"
    
    if semantic_match(name1, name2):
        print(f"{name1} and {name2} are semantically similar.")
    else:
        print(f"{name1} and {name2} are not semantically similar.")"""

import requests
import logging
import openai

# Initialize the cache
#geo_cache = {}

# Replace with your actual Google Maps API key
GOOGLE_API_KEY = OPENAI_API_KEY

# Set up logging
logging.basicConfig(level=logging.INFO)

def geocode_location(location):
    """ Get geographical coordinates using Google Maps API with caching and OpenAI integration. """
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad responses
        data = response.json()
        
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            logging.info(f"Coordinates for {location}: ({lat}, {lon})")
            return lat, lon
        else:
            logging.error(f"Error in response: {data['status']}")
            handle_openai_error(data['status'])
    except requests.exceptions.RequestException as e:
        logging.error(f"Request error for {location}: {e}")
    except Exception as e:
        logging.error(f"Unexpected error fetching geolocation for {location}: {e}")
    
    return None

def handle_openai_error(status):
    """ Handle errors by sending a request to OpenAI for further analysis. """
    try:
        openai.api_key = OPENAI_API_KEY
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "user", "content": f"Analyze the geocoding error: {status}"}
            ]
        )
        logging.info(f"OpenAI response: {response['choices'][0]['message']['content']}")
    except Exception as e:
        logging.error(f"OpenAI error: {e}")

# Example usage
"""if __name__ == "__main__":
    location = "1600 Amphitheatre Parkway, Mountain View, CA"
    coordinates = geocode_location(location)
    if coordinates:
        print(f"Coordinates for {location}: {coordinates}")
    else:
        print(f"Could not retrieve coordinates for {location}.")"""





def generate_context(entity):
    """ Generate additional context about the entity using OpenAI API. """
    prompt = f"Provide a brief description of {entity}."
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",  # or any other model you prefer
            messages=[{"role": "user", "content": prompt}]
        )
        return response['choices'][0]['message']['content']
    except Exception as e:
        print(f"Error generating context for {entity}: {e}")
        return None

import logging
from concurrent.futures import ThreadPoolExecutor

# Assuming these functions are defined elsewhere in your code
# from your_module import extract_entities, geocode_location, semantic_match, generate_context

# Set up logging
logging.basicConfig(level=logging.INFO)

def process_text(text):
    """ Process input text to extract, normalize, and geocode geospatial entities. """
    extracted_entities = extract_entities(text)
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    # Check for duplicate variations using semantic similarity
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    
                    if matched:
                        logging.info(f"Duplicate entity found: {entity} is similar to {matched}. Skipping.")
                        continue  # Skip redundant entity
                    
                    # Generate context for the entity
                    context = generate_context(entity)
                    geo_entities[entity] = {
                        "coordinates": coordinates,
                        "context": context
                    }
                    logging.info(f"Processed entity: {entity} with coordinates: {coordinates}")

            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    
    return geo_entities

# Example usage
"""if __name__ == "__main__":
    text = "Visit the Eiffel Tower in Paris and the Statue of Liberty in New York."
    result = process_text(text)
    print(result)"""


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
    roc_auc_score,
    confusion_matrix,
    classification_report,
)
import time
import joblib  # For memory usage estimation
import pandas as pd

def evaluate_model(y_true, y_pred, y_scores=None):
    """ Compute advanced evaluation metrics for the model. """
    
    # Calculate basic metrics
    precision = precision_score(y_true, y_pred, zero_division=1)
    recall = recall_score(y_true, y_pred, zero_division=1)
    f1 = f1_score(y_true, y_pred, zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    
    # Calculate ROC-AUC if scores are provided
    roc_auc = roc_auc_score(y_true, y_scores) if y_scores is not None else None
    
    # Print classification report
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:")
    print(cm)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Return metrics
    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "accuracy": accuracy,
        "roc_auc": roc_auc,
    }

def interpret_model(model, feature_names):
    """ Interpret the model using feature importance or SHAP values. """
    # Example using feature importance for tree-based models
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
        indices = np.argsort(importances)[::-1]
        
        # Print the feature ranking
        print("Feature ranking:")
        for f in range(len(feature_names)):
            print(f"{f + 1}. {feature_names[indices[f]]} ({importances[indices[f]]})")
        
        # Plot the feature importances
        plt.figure()
        plt.title("Feature importances")
        plt.bar(range(len(importances)), importances[indices], align="center")
        plt.xticks(range(len(importances)), np.array(feature_names)[indices], rotation=90)
        plt.xlim([-1, len(importances)])
        plt.show()
    else:
        print("Model does not have feature importances.")

def measure_memory_usage():
    """ Measure memory usage of the current process. """
    import os
    import psutil
    process = psutil.Process(os.getpid())
    mem_usage = process.memory_info().rss / (1024 ** 2)  # Convert to MB
    return mem_usage

def measure_speed(model, X, n_runs=100):
    """ Measure the speed (latency and throughput) of the model. """
    start_time = time.time()
    for _ in range(n_runs):
        model.predict(X)
    end_time = time.time()
    
    latency = (end_time - start_time) / n_runs  # Average latency
    throughput = n_runs / (end_time - start_time)  # Predictions per second
    return latency, throughput

# Example usage
if __name__ == "__main__":
    # Sample data
    np.random.seed(42)
    y_true = np.random.randint(0, 2, size=100)  # True labels
    y_pred = np.random.randint(0, 2, size=100)  # Predicted labels
    y_scores = np.random.rand(100)  # Predicted probabilities (for ROC-AUC)

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred, y_scores)
    print("Metrics:", metrics)

    # Interpretability (assuming a tree-based model)
    from sklearn.ensemble import RandomForestClassifier
    model = RandomForestClassifier()
    model.fit(np.random.rand(100, 10), y_true)  # Dummy training
    interpret_model(model, feature_names=[f"Feature {i}" for i in range(10)])

    # Measure memory usage
    mem_usage = measure_memory_usage()
    print(f"Memory Usage: {mem_usage:.2f} MB")

    # Measure speed
    X_test = np.random.rand(10, 10)  # Dummy test data
    latency, throughput = measure_speed(model, X_test)
    print(f"Latency: {latency:.4f} seconds, Throughput: {throughput:.2f} predictions/second")




if __name__ == "__main__":
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    main()


    coordinates = geocode_location(location)
    if coordinates:
        print(f"Coordinates for {location}: {coordinates}")
    else:
        print(f"Could not retrieve coordinates for {location}.")

    if semantic_match(name1, name2):
        print(f"{name1} and {name2} are semantically similar.")
    else:
        print(f"{name1} and {name2} are not semantically similar.")




    
    precision, recall, f1, accuracy = evaluate_model(test_texts, ground_truths)
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    sample_text = "The wildfire in Chennai has spread rapidly. Evacuations are in place for Karnataka state."
    results = process_text(text)
    print("Geospatial Entities and Coordinates:", results)
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 392
#     381 texts = [
# ...

# %%
import spacy
import requests
import json
import faiss
import pickle
import logging
import re
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import psutil
import os
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Set up logging
logging.basicConfig(level=logging.INFO)

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = "AIzaSyCKL_3TpCL7mt8dincmwy45WrFaenyosZY"

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# API Keys (Set these as environment variables)
GOOGLE_API_KEY = GOOGLE_API_KEY
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}


def extract_entities(text):
    """
    Extract named entities using Spacy & Transformer-based NER model.
    """
    doc = nlp(text)
    entities = list(set(ent.text for ent in doc.ents))
    return entities


def get_openai_embedding(text):
    """ Get embeddings from OpenAI API. """
    response = openai.Embedding.create(
        model="text-embedding-ada-002",
        input=text
    )
    return response['data'][0]['embedding']


def semantic_match(name1, name2, threshold=0.85):
    """ Use Sentence Transformers and OpenAI for semantic similarity. """
    try:
        embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
        embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
        similarity_st = util.pytorch_cos_sim(embedding1, embedding2).item()

        openai_embedding1 = get_openai_embedding(name1)
        openai_embedding2 = get_openai_embedding(name2)
        similarity_openai = util.pytorch_cos_sim(
            torch.tensor(openai_embedding1),
            torch.tensor(openai_embedding2)
        ).item()
        
        return (similarity_st + similarity_openai) / 2 >= threshold
    except Exception as e:
        logging.error(f"Error in semantic_match: {e}")
        return False


def geocode_location(location):
    """ Get geographical coordinates using Google Maps API. """
    if location in geo_cache:
        return geo_cache[location]
    
    if not GOOGLE_API_KEY:
        logging.error("Google API Key is missing.")
        return None
    
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except requests.exceptions.RequestException as e:
        logging.error(f"Request error: {e}")
    return None


def process_text(text):
    """ Extract, normalize, and geocode geospatial entities. """
    extracted_entities = extract_entities(text)
    geo_entities = {}
    
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = next((e for e in geo_entities if semantic_match(e, entity)), None)
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities


def evaluate_model(y_true, y_pred):
    """ Compute evaluation metrics. """
    precision = precision_score(y_true, y_pred, zero_division=1)
    recall = recall_score(y_true, y_pred, zero_division=1)
    f1 = f1_score(y_true, y_pred, zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()
    
    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "accuracy": accuracy
    }


def measure_memory_usage():
    """ Measure memory usage. """
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)  # Convert to MB


def measure_speed(model, X, n_runs=100):
    """ Measure model inference speed. """
    start_time = time.time()
    for _ in range(n_runs):
        model.predict(X)
    elapsed_time = time.time() - start_time
    return elapsed_time / n_runs, n_runs / elapsed_time


if __name__ == "__main__":
    test_texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    
    for text in test_texts:
        result = process_text(text)
        print(f"Geospatial Entities for '{text}':", result)

    y_true = np.random.randint(0, 2, size=100)
    y_pred = np.random.randint(0, 2, size=100)
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

    print(f"Memory Usage: {measure_memory_usage():.2f} MB")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\thinc\shims\pytorch.py:261: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import spacy
import requests
from transformers import pipeline
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score, confusion_matrix, classification_report
import openai  # Import OpenAI library
import json
import faiss
import pickle
import re
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
import joblib  # For memory usage estimation
import pandas as pd
import os
import psutil
from sklearn.ensemble import RandomForestClassifier

# Load NLP Models
nlp = spacy.load("en_core_web_trf")  # Better than 'en_core_web_sm'
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")  # For better entity similarity matching

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = "AIzaSyCKL_3TpCL7mt8dincmwy45WrFaenyosZY"

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    """
    Extract named entities from the given text using OpenAI's language model and similar examples.
    """
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))  # Return unique entities

def geocode_location(location):
    """ Get geographical coordinates using Google Maps API with caching."""
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key=your-google-api-key"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    """Use Sentence Transformers for semantic similarity matching."""
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    """ Process input text to extract, normalize, and geocode geospatial entities. """
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue  # Skip redundant entity
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    """ Compute evaluation metrics for the model. """
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

if __name__ == "__main__":
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = ground_truths
    y_pred = [["California", "Los Angeles"] , ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\thinc\shims\pytorch.py:261: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/491.2 kB ? eta -:--:--
#    -- ------------------------------------- 30.7/491.2 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/491.2 kB 653.6 kB/s eta 0:00:01
#    ------- ------------------------------- 92.2/491.2 kB 751.6 kB/s eta 0:00:01
#    -------------- ------------------------- 174.1/491.2 kB 1.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 204.8/491.2 kB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 286.7/491.2 kB 1.2 MB/s eta 0:00:01
#    ------------------------- -------------- 317.4/491.2 kB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 358.4/491.2 kB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 440.3/491.2 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 471.0/491.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 491.2/491.2 kB 1.0 MB/s eta 0:00:00
# ...

# %%
pip install pyarrow==14.0.1
# Out:
# ...
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB 220.2 kB/s eta 0:01:54
#    ---------------------------------------- 0.1/25.0 MB 328.2 kB/s eta 0:01:17
#    ---------------------------------------- 0.1/25.0 MB 479.1 kB/s eta 0:00:53
#    ---------------------------------------- 0.1/25.0 MB 532.5 kB/s eta 0:00:47
#    ---------------------------------------- 0.2/25.0 MB 583.1 kB/s eta 0:00:43
#    ---------------------------------------- 0.2/25.0 MB 562.0 kB/s eta 0:00:45
#    ---------------------------------------- 0.2/25.0 MB 628.1 kB/s eta 0:00:40
#    ---------------------------------------- 0.3/25.0 MB 632.4 kB/s eta 0:00:40
# ...

# %%
# !pip install transformers[torch]
# Out:
# ...
#    ---------------------------------------- 0.0/345.1 kB ? eta -:--:--
#    - -------------------------------------- 10.2/345.1 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/345.1 kB 660.6 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/345.1 kB 393.8 kB/s eta 0:00:01
#    ------------ ------------------------- 112.6/345.1 kB 656.4 kB/s eta 0:00:01
#    ------------------- ------------------ 174.1/345.1 kB 807.1 kB/s eta 0:00:01
#    --------------------------- ---------- 245.8/345.1 kB 942.1 kB/s eta 0:00:01
#    --------------------------- ---------- 245.8/345.1 kB 942.1 kB/s eta 0:00:01
#    -------------------------------------- 345.1/345.1 kB 973.6 kB/s eta 0:00:00
# ...

# %%
# !pip install accelerate>={ACCELERATE_MIN_VERSION}

# %%
import spacy
import requests
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import psutil
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from datasets import load_dataset, Dataset

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = "AIzaSyCKL_3TpCL7mt8dincmwy45WrFaenyosZY"

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))

def geocode_location(location):
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def fine_tune_model(train_data):
    # Convert to Hugging Face Dataset
    dataset = Dataset.from_dict(train_data)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
    )

    # Initialize Trainer
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset,  # For simplicity, using the same dataset for evaluation
    )

    # Train the model
    trainer.train()

def augment_data(texts, entities):
    # Simple data augmentation by paraphrasing or adding noise
    augmented_texts = []
    for text in texts:
        # Example: Add noise or paraphrase (this is a placeholder for actual augmentation logic)
        augmented_texts.append(text + " [NOISE]")
    return augmented_texts, entities

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    # Flatten ground truths for evaluation
    y_true = [item for sublist in ground_truths for item in sublist]
    y_pred = [["California", "Los Angeles County"], ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions

    # Data Augmentation
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)

    # Fine-tune the model with augmented data
    fine_tune_model({"text": augmented_texts, "entities": augmented_entities})

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ...

# %%
import spacy
import requests
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import psutil
from sklearn.model_selection import train_test_split
from datasets import load_dataset, Dataset

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))

def geocode_location(location):
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def fine_tune_model(train_data):
    # Convert to Hugging Face Dataset
    dataset = Dataset.from_dict(train_data)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False  # Prevents the ValueError
    )

    # Initialize Trainer
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset,  # For simplicity, using the same dataset for evaluation
    )

    # Train the model
    trainer.train()

def augment_data(texts, entities):
    # Simple data augmentation by paraphrasing or adding noise
    augmented_texts = []
    augmented_entities = []
    for text, entity_list in zip(texts, entities):
        # Example: Add noise or paraphrase (this is a placeholder for actual augmentation logic)
        augmented_texts.append(text + " [NOISE]")
        augmented_entities.append(entity_list)  # Keep the same entities for simplicity
    return augmented_texts, augmented_entities

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    # Flatten ground truths for evaluation
    y_true = [item for sublist in ground_truths for item in sublist]
    y_pred = [["California", "Los Angeles County"], ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions

    # Data Augmentation
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)

    # Fine-tune the model with augmented data
    fine_tune_model({"text": augmented_texts, "entities": augmented_entities})

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 192
#     189     print("Metrics:", metrics)
#     191 if __name__ == "__main__":
# --> 192     main()
#
# ...

# %%
import spacy
import requests
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import Dataset, load_dataset

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = GOOGLE_API_KEY

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = OPENAI_API_KEY
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))

def geocode_location(location):
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def fine_tune_model(train_data):
    # Convert to Hugging Face Dataset
    dataset = Dataset.from_dict(train_data)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False  # Prevents the ValueError
    )

    # Initialize Trainer
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset,  # For simplicity, using the same dataset for evaluation
    )

    # Train the model
    trainer.train()

def augment_data(texts, entities):
    # Simple data augmentation by paraphrasing or adding noise
    augmented_texts = []
    augmented_entities = []
    for text, entity_list in zip(texts, entities):
        # Example: Add noise or paraphrase (this is a placeholder for actual augmentation logic)
        augmented_texts.append(text + " [NOISE]")
        # Create a list of dictionaries for entities
        entity_dicts = [{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list]
        augmented_entities.append(entity_dicts)  # Keep the same entities for simplicity
    return augmented_texts, augmented_entities

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    # Flatten ground truths for evaluation
    y_true = [item for sublist in ground_truths for item in sublist]
    y_pred = [["California", "Los Angeles County"], ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions

    # Data Augmentation
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)

    # Fine-tune the model with augmented data
    fine_tune_model({"text": augmented_texts, "entities": augmented_entities})

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 190
#     187     print("Metrics:", metrics)
#     189 if __name__ == "__main__":
# --> 190     main()
#
# ...

# %%
import spacy
import requests
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import Dataset

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = GOOGLE_API_KEY

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = OPENAI_API_KEY
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))

def geocode_location(location):
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def fine_tune_model(train_data):
    # Convert to Hugging Face Dataset
    dataset = Dataset.from_dict(train_data)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False  # Prevents the ValueError
    )

    # Initialize Trainer
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset,  # For simplicity, using the same dataset for evaluation
    )

    # Train the model
    trainer.train()

def augment_data(texts, entities):
    # Simple data augmentation by paraphrasing or adding noise
    augmented_texts = []
    augmented_entities = []
    for text, entity_list in zip(texts, entities):
        # Example: Add noise or paraphrase (this is a placeholder for actual augmentation logic)
        augmented_texts.append(text + " [NOISE]")
        # Create a list of dictionaries for entities
        entity_dicts = [{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list]
        augmented_entities.append(entity_dicts)  # Keep the same entities for simplicity
    return augmented_texts, augmented_entities

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    # Flatten ground truths for evaluation
    y_true = [item for sublist in ground_truths for item in sublist]
    y_pred = [["California", "Los Angeles County"], ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions

    # Data Augmentation
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)

    # Prepare training data
    train_data = {
        "text": augmented_texts,
        "entities": augmented_entities
    }

    # Fine-tune the model with augmented data
    fine_tune_model(train_data)

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 196
#     193     print("Metrics:", metrics)
#     195 if __name__ == "__main__":
# --> 196     main()
#
# ...

# %%
import spacy
import requests
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from concurrent.futures import ThreadPoolExecutor
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import openai
import json
import logging
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import Dataset

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# Google API Key (Replace this with your own)
GOOGLE_API_KEY = GOOGLE_API_KEY

# OpenAI API Key (Replace this with your own)
OPENAI_API_KEY = OPENAI_API_KEY
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    You are tasked with extracting named entities from a given text. Named entities can be organizations, locations, dates, etc.
    The output should be in the following JSON format, between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Consider the following examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    if match:
        entities_json = match.group(1)
        entities = json.loads(entities_json).get("entities", [])
    else:
        entities = []

    return list(set(entities))

def geocode_location(location):
    if location in geo_cache:
        logging.info(f"Cache hit for location: {location}")
        return geo_cache[location]

    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lon = data["results"][0]["geometry"]["location"]["lng"]
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    embedding1 = semantic_model.encode(name1, convert_to_tensor=True)
    embedding2 = semantic_model.encode(name2, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(embedding1, embedding2).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates:
                    matched = None
                    for existing in geo_entities:
                        if semantic_match(existing, entity):
                            matched = existing
                            break
                    if matched:
                        continue
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def fine_tune_model(train_data):
    # Convert to Hugging Face Dataset
    dataset = Dataset.from_dict(train_data)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False  # Prevents the ValueError
    )

    # Initialize Trainer
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset,  # For simplicity, using the same dataset for evaluation
    )

    # Train the model
    trainer.train()

def augment_data(texts, entities):
    # Simple data augmentation by paraphrasing or adding noise
    augmented_texts = []
    augmented_entities = []
    for text, entity_list in zip(texts, entities):
        # Example: Add noise or paraphrase (this is a placeholder for actual augmentation logic)
        augmented_texts.append(text + " [NOISE]")
        # Create a list of dictionaries for entities
        entity_dicts = [{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list]
        augmented_entities.append(entity_dicts)  # Keep the same entities for simplicity
    return augmented_texts, augmented_entities

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]

    # Flatten ground truths for evaluation
    y_true = [item for sublist in ground_truths for item in sublist]
    y_pred = [["California", "Los Angeles County"], ["New York", "Washington DC"], ["Tokyo", "Japan"]]  # Replace with actual predictions

    # Data Augmentation
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)

    # Prepare training data
    train_data = {
        "text": augmented_texts,
        "entities": augmented_entities
    }

    # Fine-tune the model with augmented data
    fine_tune_model(train_data)

    # Evaluate the model
    metrics = evaluate_model(y_true, y_pred)
    print("Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 196
#     193     print("Metrics:", metrics)
#     195 if __name__ == "__main__":
# --> 196     main()
#
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# API Keys (Replace with environment variables in production)
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    return json.loads(match.group(1)).get("entities", []) if match else []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[entity for entity in entity_list] for entity_list in entities]
    return augmented_texts, augmented_entities

def fine_tune_model(train_data):
    dataset = Dataset.from_dict({
        "text": train_data["text"],
        "entities": train_data["entities"]  # Ensure entities are a list of lists
    })
    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False
    )
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset
    )
    trainer.train()

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = [entity for sublist in ground_truths for entity in sublist]
    y_pred = y_true  # Placeholder for actual predictions
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    fine_tune_model(train_data)
    print("Metrics:", evaluate_model(y_true, y_pred))

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 152
#     149     print("Metrics:", evaluate_model(y_true, y_pred))
#     151 if __name__ == "__main__":
# --> 152     main()
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
from pandas import json_normalize

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# API Keys (Replace with environment variables in production)
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    return json.loads(match.group(1)).get("entities", []) if match else []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def fine_tune_model(train_data):
    dataset = Dataset.from_dict({
        "text": train_data["text"],
        "entities": train_data["entities"]
    })

    # You can inspect or map dataset here if needed

    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False
    )

    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset
    )

    trainer.train()


def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = [entity for sublist in ground_truths for entity in sublist]
    y_pred = y_true  # Placeholder for actual predictions
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    fine_tune_model(train_data)
    print("Metrics:", evaluate_model(y_true, y_pred))

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 159
#     156     print("Metrics:", evaluate_model(y_true, y_pred))
#     158 if __name__ == "__main__":
# --> 159     main()
#
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")

# API Keys (Replace with environment variables in production)
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# Cache for geocoded locations
geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    return json.loads(match.group(1)).get("entities", []) if match else []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def fine_tune_model(train_data):
    # ✅ FIX: Convert to list of dicts for Dataset.from_list
    records = []
    for text, entity_list in zip(train_data["text"], train_data["entities"]):
        records.append({
            "text": text,
            "entities": entity_list
        })
    
    dataset = Dataset.from_list(records)  # ✅ SAFE for nested dicts
    # ❌ Removed json_normalize(dataset) – causes RuntimeError

    training_args = TrainingArguments(
        output_dir='./results',
        num_train_epochs=3,
        per_device_train_batch_size=8,
        save_steps=10_000,
        save_total_limit=2,
        evaluation_strategy="epoch",
        logging_dir='./logs',
        remove_unused_columns=False
    )
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=dataset,
        eval_dataset=dataset
    )
    trainer.train()

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = [entity for sublist in ground_truths for entity in sublist]
    y_pred = y_true  # Placeholder for actual predictions
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    fine_tune_model(train_data)
    print("Metrics:", evaluate_model(y_true, y_pred))

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 159
#     156     print("Metrics:", evaluate_model(y_true, y_pred))
#     158 if __name__ == "__main__":
# --> 159     main()
#
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments, AutoTokenizer
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": text}
        ]
    )

    response_text = response['choices'][0]['message']['content']
    match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
    return json.loads(match.group(1)).get("entities", []) if match else []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"], truncation=True, padding="max_length", max_length=128, return_offsets_mapping=True
    )
    labels = []
    for i, offset_mapping in enumerate(tokenized_inputs["offset_mapping"]):
        entity_list = examples["entities"][i]
        label_ids = []
        for start_char, end_char in offset_mapping:
            label = "O"
            for ent in entity_list:
                if start_char >= ent["start"] and end_char <= ent["end"]:
                    label = f"B-{ent['label']}"
                    break
            label_ids.append(label)
        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    tokenized_inputs.pop("offset_mapping")
    return tokenized_inputs

def fine_tune_model(train_data):
    dataset = Dataset.from_dict({
        "text": train_data["text"],
        "entities": train_data["entities"]
    })
    tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=4,
        evaluation_strategy="epoch",
        save_total_limit=2,
        logging_dir="./logs",
        remove_unused_columns=False,
    )
    trainer = Trainer(
        model=nlp_ner.model,
        args=training_args,
        train_dataset=tokenized_dataset,
        eval_dataset=tokenized_dataset,
        tokenizer=tokenizer,
    )
    trainer.train()

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = [entity for sublist in ground_truths for entity in sublist]
    y_pred = y_true  # Placeholder
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    fine_tune_model(train_data)
    print("Metrics:", evaluate_model(y_true, y_pred))

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14488\3571711836.py:147: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# ...

# %%
from transformers import BertTokenizerFast, BertForTokenClassification, Trainer, TrainingArguments, DataCollatorForTokenClassification
from datasets import Dataset
import torch

# Sample data - texts as strings and entities as span dicts
texts = ["New York is big", "Hello Bangalore"]
entities = [
    [{"start": 0, "end": 8, "label": "B-LOC"}],
    [{"start": 6, "end": 15, "label": "B-LOC"}]
]

# Labels must match the model's label set
label_list = ['O', 'B-LOC']
label_to_id = {l: i for i, l in enumerate(label_list)}
id_to_label = {i: l for l, i in label_to_id.items()}

# Load tokenizer and model
model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"
tokenizer = BertTokenizerFast.from_pretrained(model_name)
model = BertForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))

# Prepare dataset
raw_dataset = Dataset.from_dict({"text": texts, "entities": entities})

# Tokenization with label alignment
def tokenize_and_align_labels(example):
    tokenized_input = tokenizer(
        example["text"],
        truncation=True,
        padding="max_length",
        max_length=128,
        return_offsets_mapping=True
    )
    
    labels = ["O"] * len(tokenized_input["input_ids"])
    entities = example["entities"]

    for ent in entities:
        for idx, (start, end) in enumerate(tokenized_input["offset_mapping"]):
            if start >= ent["start"] and end <= ent["end"]:
                labels[idx] = ent["label"]

    # Convert label strings to IDs
    label_ids = [label_to_id.get(label, 0) for label in labels]
    tokenized_input["labels"] = label_ids
    tokenized_input.pop("offset_mapping")
    return tokenized_input

# Apply mapping
tokenized_dataset = raw_dataset.map(tokenize_and_align_labels)

# Trainer setup
args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="no",
    per_device_train_batch_size=2,
    num_train_epochs=1,
    logging_steps=10,
    remove_unused_columns=False
)

data_collator = DataCollatorForTokenClassification(tokenizer)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# Train
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 20
#      18 model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"
#      19 tokenizer = BertTokenizerFast.from_pretrained(model_name)
# ---> 20 model = BertForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))
#      22 # Prepare dataset
#      23 raw_dataset = Dataset.from_dict({"text": texts, "entities": entities})
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4224, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4214     if dtype_orig is not None:
#    4215         torch.set_default_dtype(dtype_orig)
#    4217     (
#    4218         model,
#    4219         missing_keys,
# ...

# %%
from transformers import BertTokenizerFast, BertForTokenClassification, Trainer, TrainingArguments, DataCollatorForTokenClassification
from datasets import Dataset
import torch

# Sample data - texts as strings and entities as span dicts
texts = ["New York is big", "Hello Bangalore"]
entities = [
    [{"start": 0, "end": 8, "label": "B-LOC"}],  # "New York"
    [{"start": 6, "end": 15, "label": "B-LOC"}]  # "Bangalore"
]

# Define label scheme
label_list = ['O', 'B-LOC']  # Expand to ['O', 'B-LOC', 'I-LOC'] if needed
label_to_id = {l: i for i, l in enumerate(label_list)}
id_to_label = {i: l for l, i in label_to_id.items()}

# Load tokenizer and model
model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"
tokenizer = BertTokenizerFast.from_pretrained(model_name)
model = BertForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))

# Prepare dataset
raw_dataset = Dataset.from_dict({"text": texts, "entities": entities})

# Tokenization with label alignment
def tokenize_and_align_labels(example):
    tokenized_input = tokenizer(
        example["text"],
        truncation=True,
        padding="max_length",
        max_length=128,
        return_offsets_mapping=True,
        return_tensors=None
    )
    
    labels = ["O"] * len(tokenized_input["input_ids"])
    offsets = tokenized_input["offset_mapping"]
    entities = example["entities"]

    for ent in entities:
        ent_start = ent["start"]
        ent_end = ent["end"]
        ent_label = ent["label"]

        for idx, (start, end) in enumerate(offsets):
            # Skip special tokens
            if start == end == 0:
                continue
            if start >= ent_start and end <= ent_end:
                labels[idx] = ent_label  # If you have I-LOC, you can differentiate the first token

    # Convert label strings to IDs
    tokenized_input["labels"] = [label_to_id[label] for label in labels]
    tokenized_input.pop("offset_mapping")
    return tokenized_input

# Apply mapping
tokenized_dataset = raw_dataset.map(tokenize_and_align_labels)

# Trainer setup
args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="no",
    per_device_train_batch_size=2,
    num_train_epochs=1,
    logging_steps=10,
    remove_unused_columns=False
)

data_collator = DataCollatorForTokenClassification(tokenizer)

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
)

# Train
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 20
#      18 model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"
#      19 tokenizer = BertTokenizerFast.from_pretrained(model_name)
# ---> 20 model = BertForTokenClassification.from_pretrained(model_name, num_labels=len(label_list))
#      22 # Prepare dataset
#      23 raw_dataset = Dataset.from_dict({"text": texts, "entities": entities})
#
# File ~\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4224, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4214     if dtype_orig is not None:
#    4215         torch.set_default_dtype(dtype_orig)
#    4217     (
#    4218         model,
#    4219         missing_keys,
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor, as_completed
from transformers import pipeline, Trainer, TrainingArguments, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
from typing import List, Dict, Tuple, Optional

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

# Cache for geocoding results
geo_cache = {}

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

def extract_entities(text: str, examples: List[Tuple[str, List[str]]]) -> List[str]:
    """
    Extract named entities from text using GPT-4.
    """
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": text}
            ]
        )
        response_text = response['choices'][0]['message']['content']
        match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
        if match:
            return json.loads(match.group(1)).get("entities", [])
    except Exception as e:
        logging.error(f"Error extracting entities: {e}")
    return []

def geocode_location(location: str) -> Optional[Tuple[float, float]]:
    """
    Geocode a location using Google Maps API.
    """
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error geocoding {location}: {e}")
    return None

def semantic_match(name1: str, name2: str, threshold: float = 0.85) -> bool:
    """
    Check if two names are semantically similar.
    """
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text: str) -> Dict[str, Dict[str, Tuple[float, float]]]:
    """
    Process text to extract and geocode entities.
    """
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in as_completed(futures):
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true: List[str], y_pred: List[str]) -> Dict[str, float]:
    """
    Evaluate model performance using precision, recall, F1, and accuracy.
    """
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts: List[str], entities: List[List[str]]) -> Tuple[List[str], List[List[Dict[str, int]]]]:
    """
    Augment data by adding noise and aligning entity labels.
    """
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def tokenize_and_align_labels(examples: Dict[str, List]) -> Dict[str, List]:
    """
    Tokenize text and align entity labels with tokens.
    """
    # Tokenize the text with padding and truncation
    tokenized_inputs = tokenizer(
        examples["texts"],
        truncation=True,
        padding="max_length",
        max_length=128,
        return_offsets_mapping=True,
        is_split_into_words=False  # Ensure the text is treated as a single string
    )

    # Align labels with tokens
    labels = []
    for i, offset_mapping in enumerate(tokenized_inputs["offset_mapping"]):
        entity_list = examples["entities"][i]
        label_ids = []
        for start_char, end_char in offset_mapping:
            label = "O"  # Default label (Outside)
            for ent in entity_list:
                if start_char >= ent["start"] and end_char <= ent["end"]:
                    label = f"B-{ent['label']}"  # Beginning of entity
                    break
            label_ids.append(label)
        labels.append(label_ids)

    # Add labels to the tokenized inputs
    tokenized_inputs["labels"] = labels
    tokenized_inputs.pop("offset_mapping")  # Remove offset mapping as it's no longer needed
    return tokenized_inputs

def fine_tune_model(train_data: Dict[str, List]) -> None:
    """
    Fine-tune the NER model using the provided training data.
    """
    # Convert training data to a Hugging Face Dataset
    dataset = Dataset.from_dict({
        "text": train_data["text"],
        "entities": train_data["entities"]
    })

    # Tokenize and align labels
    tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)

    # Define training arguments
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=4,
        evaluation_strategy="epoch",
        save_total_limit=2,
        logging_dir="./logs",
        remove_unused_columns=False,
    )

    # Initialize the Trainer
    trainer = Trainer(
        model=AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english"),
        args=training_args,
        train_dataset=tokenized_dataset,
        eval_dataset=tokenized_dataset,
        tokenizer=tokenizer,
    )

    # Fine-tune the model
    trainer.train()

def augment_data(texts: List[str], entities: List[List[str]]) -> Tuple[List[str], List[List[Dict[str, int]]]]:
    """
    Augment data by adding noise and aligning entity labels.
    """
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = []
    for text, entity_list in zip(texts, entities):
        entities_with_offsets = []
        for entity in entity_list:
            start = text.find(entity)
            if start != -1:  # Ensure the entity exists in the text
                entities_with_offsets.append({
                    "start": start,
                    "end": start + len(entity),
                    "label": "LOCATION"
                })
        augmented_entities.append(entities_with_offsets)
    return augmented_texts, augmented_entities

def main():
    """
    Main function to demonstrate the workflow.
    """
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    y_true = [entity for sublist in ground_truths for entity in sublist]
    y_pred = y_true  # Placeholder
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    fine_tune_model(train_data)
    print("Metrics:", evaluate_model(y_true, y_pred))

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset, DatasetDict
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

geo_cache = {}
label2id = {"O": 0, "B-LOCATION": 1}
id2label = {0: "O", 1: "B-LOCATION"}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": text}
            ]
        )
        response_text = response['choices'][0]['message']['content']
        match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
        return json.loads(match.group(1)).get("entities", []) if match else []
    except Exception as e:
        logging.error(f"GPT-4 entity extraction error: {e}")
        return []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"], truncation=True, padding="max_length", max_length=128, return_offsets_mapping=True
    )
    labels = []
    for i, offset_mapping in enumerate(tokenized_inputs["offset_mapping"]):
        entity_list = examples["entities"][i]
        label_ids = []
        for start_char, end_char in offset_mapping:
            label = "O"
            for ent in entity_list:
                if start_char >= ent["start"] and end_char <= ent["end"]:
                    label = f"B-{ent['label']}"
                    break
            label_ids.append(label2id.get(label, 0))
        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    tokenized_inputs.pop("offset_mapping")
    return tokenized_inputs

def fine_tune_model(train_data):
    dataset = Dataset.from_dict({"text": train_data["text"], "entities": train_data["entities"]})
    split_dataset = dataset.train_test_split(test_size=0.2)
    tokenized_train = split_dataset["train"].map(tokenize_and_align_labels, batched=True)
    tokenized_eval = split_dataset["test"].map(tokenize_and_align_labels, batched=True)
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=4,
        evaluation_strategy="epoch",
        save_total_limit=2,
        logging_dir="./logs",
        remove_unused_columns=False,
    )
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_train,
        eval_dataset=tokenized_eval,
        tokenizer=tokenizer,
    )
    trainer.train()
    predictions, labels, _ = trainer.predict(tokenized_eval)
    y_pred = np.argmax(predictions, axis=2).flatten()
    y_true = np.array(labels).flatten()
    return evaluate_model(y_true, y_pred)

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    print("Training model and evaluating performance...")
    metrics = fine_tune_model(train_data)
    print("Final Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ...

# %%
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset, DatasetDict
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "YOUR_OPENAI_API_KEY"
openai.api_key = OPENAI_API_KEY

geo_cache = {}
label2id = {"O": 0, "B-LOCATION": 1}
id2label = {0: "O", 1: "B-LOCATION"}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    ```
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```
    Examples:
    {examples_text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": text}
            ]
        )
        response_text = response['choices'][0]['message']['content']
        match = re.search(r'```json\n(.*?)\n```', response_text, re.DOTALL)
        return json.loads(match.group(1)).get("entities", []) if match else []
    except Exception as e:
        logging.error(f"GPT-4 entity extraction error: {e}")
        return []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred)
    print("Classification Report:")
    print(classification_report(y_true, y_pred))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()
    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

def augment_data(texts, entities):
    augmented_texts = [text + " [NOISE]" for text in texts]
    augmented_entities = [[{"start": text.index(entity), "end": text.index(entity) + len(entity), "label": "LOCATION"} for entity in entity_list] for text, entity_list in zip(texts, entities)]
    return augmented_texts, augmented_entities

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["text"], truncation=True, padding="max_length", max_length=128, return_offsets_mapping=True
    )
    labels = []
    for i, offset_mapping in enumerate(tokenized_inputs["offset_mapping"]):
        entity_list = examples["entities"][i]
        label_ids = []
        for start_char, end_char in offset_mapping:
            label = "O"
            for ent in entity_list:
                if start_char >= ent["start"] and end_char <= ent["end"]:
                    label = f"B-{ent['label']}"
                    break
            label_ids.append(label2id.get(label, 0))
        labels.append(label_ids)
    tokenized_inputs["labels"] = labels
    tokenized_inputs.pop("offset_mapping")
    return tokenized_inputs

def fine_tune_model(train_data):
    dataset = Dataset.from_dict({"text": train_data["text"], "entities": train_data["entities"]})
    split_dataset = dataset.train_test_split(test_size=0.2)
    tokenized_train = split_dataset["train"].map(tokenize_and_align_labels, batched=True)
    tokenized_eval = split_dataset["test"].map(tokenize_and_align_labels, batched=True)
    training_args = TrainingArguments(
        output_dir="./results",
        num_train_epochs=3,
        per_device_train_batch_size=4,
        evaluation_strategy="epoch",
        save_total_limit=2,
        logging_dir="./logs",
        remove_unused_columns=False,
    )
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_train,
        eval_dataset=tokenized_eval,
        tokenizer=tokenizer,
    )
    trainer.train()
    predictions, labels, _ = trainer.predict(tokenized_eval)
    y_pred = np.argmax(predictions, axis=2).flatten()
    y_true = np.array(labels).flatten()
    return evaluate_model(y_true, y_pred)

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths = [
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    print("Training model and evaluating performance...")
    metrics = fine_tune_model(train_data)
    print("Final Metrics:", metrics)

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# ...

# %%
import os
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, Trainer, TrainingArguments, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer, util
from datasets import Dataset
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, classification_report
import time

# Load NLP Models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "AIzaSyCKL_3TpCL7mt8dincmwy45WrFaenyosZY"
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

if not GOOGLE_API_KEY or not OPENAI_API_KEY:
    raise ValueError("API keys must be set in environment variables.")

geo_cache = {}
label2id = {"O": 0, "B-LOCATION": 1}
id2label = {0: "O", 1: "B-LOCATION"}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:
    
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    
    Examples:
    {examples_text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": text}
            ]
        )
        response_text = response['choices'][0]['message']['content']
        match = re.search(r'json\n(.*?)\n```', response_text, re.DOTALL)
        return json.loads(match.group(1)).get("entities", []) if match else []
    except Exception as e:
        logging.error(f"GPT-4 entity extraction error: {e}")
        return []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    time.sleep(1)  # Rate limiting
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}. URL: {url}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def process_text(text):
    extracted_entities = extract_entities(text, [])
    geo_entities = {}
    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
        for future in futures:
            entity = futures[future]
            try:
                coordinates = future.result()
                if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                    geo_entities[entity] = {"coordinates": coordinates}
            except Exception as e:
                logging.error(f"Error processing entity {entity}: {e}")
    return geo_entities

def evaluate_model(y_true, y_pred):
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    accuracy = accuracy_score(y_true, y_pred)
    return precision, recall, f1, accuracy

def chatbot_response(user_input):
    risk_level = assess_risk(user_input)
    response = f"The risk level for your input is: {risk_level}. How can I assist you further?"
    return response

def assess_risk(text):
    # Placeholder for risk assessment logic
    if "emergency" in text.lower() or "danger" in text.lower():
        return "High"
    elif "alert" in text.lower():
        return "Medium"
    else:
        return "Low"

def main():
    texts = [
        "The wildfire in California has spread rapidly. Evacuations are in place for Los Angeles County.",
        "New York and Washington DC are experiencing heavy snowfall.",
        "A major earthquake struck Tokyo, Japan early this morning."
    ]
    ground_truths =[
        ["California", "Los Angeles County"],
        ["New York", "Washington DC"],
        ["Tokyo", "Japan"]
    ]
    augmented_texts, augmented_entities = augment_data(texts, ground_truths)
    train_data = {"text": augmented_texts, "entities": augmented_entities}
    print("Training model and evaluating performance...")
   # metrics = fine_tune_model(train_data)
    #print("Final Metrics:", metrics)
    #while True:
     #   user_input = input("You: ")
      #  if user_input.lower() in ["exit", "quit"]:
       #     break
        #response = chatbot_response(user_input)
        #print(f"Chatbot: {response}")
if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# ...

# %%
import os
import spacy
import requests
import re
import json
import logging
import openai
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from concurrent.futures import ThreadPoolExecutor
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import time

# Load NLP models
nlp = spacy.load("en_core_web_trf")
nlp_ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", aggregation_strategy="simple")
semantic_model = SentenceTransformer("all-MiniLM-L6-v2")
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

# API Keys
GOOGLE_API_KEY = "YOUR_GOOGLE_API_KEY"
OPENAI_API_KEY = "sk-aBco5iRh7B8gHAuZiOq1NyQTsxm4NGeISaelPC7IqYT3BlbkFJ4iC-kQszh4jTUOyJ7V6aNENzWG_048JDGbPrhQVGYA"
openai.api_key = OPENAI_API_KEY

geo_cache = {}

def extract_entities(text, examples):
    examples_text = "\n".join([f"Text: {ex[0]}\nExtracted Entities: {ex[1]}" for ex in examples])
    system_prompt = f"""
    Extract named entities from the text. Return JSON format between 3 backticks:

    ```json
    {{"entities": ["ENTITY_A", "ENTITY_B"]}}
    ```

    Examples:
    {examples_text}
    """

    try:
        response = openai.ChatCompletion.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": text}
            ]
        )
        response_text = response['choices'][0]['message']['content']
        match = re.search(r'```json\s*(.*?)```', response_text, re.DOTALL)
        return json.loads(match.group(1)).get("entities", []) if match else []
    except Exception as e:
        logging.error(f"GPT-4 entity extraction error: {e}")
        return []

def geocode_location(location):
    if location in geo_cache:
        return geo_cache[location]
    time.sleep(1)  # rate limiting
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={GOOGLE_API_KEY}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()
        if data["status"] == "OK":
            lat, lon = data["results"][0]["geometry"]["location"].values()
            geo_cache[location] = (lat, lon)
            return lat, lon
    except Exception as e:
        logging.error(f"Error fetching geolocation for {location}: {e}. URL: {url}")
    return None

def semantic_match(name1, name2, threshold=0.85):
    similarity = util.pytorch_cos_sim(
        semantic_model.encode(name1, convert_to_tensor=True),
        semantic_model.encode(name2, convert_to_tensor=True)
    ).item()
    return similarity >= threshold

def assess_risk(text):
    if any(word in text.lower() for word in ["emergency", "fire", "explosion", "earthquake", "flood", "tsunami", "danger", "evacuate"]):
        return "High"
    elif "alert" in text.lower():
        return "Medium"
    else:
        return "Low"

def chatbot_response(user_input):
    extracted_entities = extract_entities(user_input, [])
    geo_entities = {}
    response_lines = []

    risk_level = assess_risk(user_input)
    response_lines.append(f"Risk assessment: **{risk_level}**.")

    if extracted_entities:
        with ThreadPoolExecutor() as executor:
            futures = {executor.submit(geocode_location, entity): entity for entity in extracted_entities}
            for future in futures:
                entity = futures[future]
                try:
                    coordinates = future.result()
                    if coordinates and not any(semantic_match(existing, entity) for existing in geo_entities):
                        geo_entities[entity] = coordinates
                        lat, lon = coordinates
                        response_lines.append(f"Location identified: **{entity}** (Lat: {lat}, Lon: {lon})")
                except Exception as e:
                    logging.error(f"Error processing entity {entity}: {e}")
    
    if risk_level == "High" and geo_entities:
        response_lines.append("Emergency services are on the way to the affected locations.")
    elif risk_level == "Medium":
        response_lines.append("Please stay alert and monitor local authorities for updates.")
    else:
        response_lines.append("No immediate danger detected.")

    return "\n".join(response_lines)

def main():
    print("Disaster Response Chatbot. Type your message or 'exit' or 'E' to quit.")
    while True:
        user_input = input("You: ")
        if user_input.lower() in ["exit", "quit","close"]:
            break
        response = chatbot_response(user_input)
        print(f"Chatbot:\n{response}\n")

if __name__ == "__main__":
    main()
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# ...
